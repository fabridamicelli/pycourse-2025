# %% [markdown]
# #

# %%
# %%time

print(1)
# Out:
# 1
# CPU times: user 49 μs, sys: 12 μs, total: 61 μs
# Wall time: 63.4 μs

# %%
# %%timeit

print
# Out:
# 7.94 ns ± 0.0483 ns per loop (mean ± std. dev. of 7 runs, 100,000,000 loops each)

# %%
ls
# Out:
# getting-started.ipynb

# %%
ls ../
# Out:
# README.md  notebooks/  pyproject.toml  src/  uv.lock

# %%
ls ../src/
# Out:
# pycourse2/

# %%
1 +213
# Out:
# 214

# %%
1.2
# Out:
# 1.2

# %%
type(1.2)
# Out:
# float

# %%
1 + 2
# Out:
# 3

# %%
1 + 2.3
# Out:
# 3.3

# %%
3.4 + 3.
# Out:
# 6.4

# %%
print("hello")
# Out:
# hello

# %%
"hello".capitalize()
# Out:
# 'Hello'

# %%
"hello".upper()
# Out:
# 'HELLO'

# %%
"s".upper()
# Out:
# 'S'

# %%
" hello".startswith("he")
# Out:
# False

# %%
" hello".endswith("lo")
# Out:
# True

# %%
"hello {name}"
# Out:
# 'hello {name}'

# %%
name = "fabri"
f"hello {name}"
# Out:
# 'hello fabri'

# %%
name.upper()
# Out:
# 'FABRI'

# %%
f"hello {name.upper()}"
# Out:
# 'hello FABRI'

# %%
short = [1,2,3]

# %%
short
# Out:
# [1, 2, 3]

# %%
short[0] = "Hlloe"

# %%
short
# Out:
# ['Hlloe', 2, 3]

# %%
short.append("anohter name")

# %%
short
# Out:
# ['Hlloe', 2, 3, 'anohter name']

# %%
short.remove(2)

# %%
short
# Out:
# ['Hlloe', 3, 'anohter name']

# %%
short.remove(2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 short.remove(2)
#
# ValueError: list.remove(x): x not in list

# %%
name = "fabrizio"

# %%
name[0: 3]
# Out:
# 'fab'

# %%
name[: 3]
# Out:
# 'fab'

# %%
name
# Out:
# 'fabrizio'

# %%
name[len(name)-1]
# Out:
# 'o'

# %%
name[-1]
# Out:
# 'o'

# %%
name[-2]
# Out:
# 'i'

# %%
name
# Out:
# 'fabrizio'

# %%
name[-1:0:-1]
# Out:
# 'oizirba'

# %%
short
# Out:
# ['Hlloe', 3, 'anohter name']

# %%
short[::2]
# Out:
# ['Hlloe', 'anohter name']

# %%
"hello world".split()
# Out:
# ['hello', 'world']

# %%
"hello-happy-world".split("-")
# Out:
# ['hello', 'happy', 'world']

# %%
# Out:
# ['hello', 'happy', 'world']

# %%
short
# Out:
# ['Hlloe', 3, 'anohter name']

# %%
short[1] = "football"

# %%
short
# Out:
# ['Hlloe', 'football', 'anohter name']

# %%
mytuple = (1,2,"hello")
mytuple
# Out:
# (1, 2, 'hello')

# %%
mytuple[2] = "ciao"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 mytuple[2] = "ciao"
#
# TypeError: 'tuple' object does not support item assignment

# %%
mytuple = 1,2,2,3,3,4

# %%
s = set(mytuple)
s
# Out:
# {1, 2, 3, 4}

# %%
s.add("hellO")

# %%
s
# Out:
# {1, 2, 3, 4, 'hellO'}

# %%
s.add(1)

# %%
s
# Out:
# {1, 2, 3, 4, 'hellO'}

# %%
name
# Out:
# 'fabrizio'

# %%
list(name)
# Out:
# ['f', 'a', 'b', 'r', 'i', 'z', 'i', 'o']

# %%
name
# Out:
# 'fabrizio'

# %%
"f" in name
# Out:
# True

# %%
s = {1,2,3}

# %%
s
# Out:
# {1, 2, 3}

# %%
d = {1:2}

# %%
d
# Out:
# {1: 2}

# %%
d[1]
# Out:
# 2

# %%
word2num = {
    "learning": 1,
    "python": 2,
    "is": 3,
    "fun": 4
}
word2num
# Out:
# {'learning': 1, 'python': 2, 'is': 3, 'fun': 4}

# %%
word2num['is']
# Out:
# 3

# %%
items = [
    ("one", 1),
    ("two", 2),
    ("three", 3),
]
items
# Out:
# [('one', 1), ('two', 2), ('three', 3)]

# %%
dd = dict(items)

# %%
dd
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
dd.items()
# Out:
# dict_items([('one', 1), ('two', 2), ('three', 3)])

# %%
dd.keys()
# Out:
# dict_keys(['one', 'two', 'three'])

# %%
dd.values()
# Out:
# dict_values([1, 2, 3])

# %%
t = (1,2)

# %%
a,b = t

# %%
a
# Out:
# 1

# %%
for smt in dd.items():
    print(smt)
# Out:
# ('one', 1)
# ('two', 2)
# ('three', 3)

# %%
for k,v in dd.items():
    print(f"the key {k} maps to {v}")
# Out:
# the key one maps to 1
# the key two maps to 2
# the key three maps to 3

# %%
# TODO
# 
9, 11, 12, 14, [13]

# %%
fruits = {
    "apple": "red",
    "banana": "yellow"
}

# %%
if "apple" in fruits:
    fruits["apple"]
else:
    "nothing"
# Out:
# 'red'

# %%
fruits.get("apple", "nothing")
# Out:
# 'red'

# %%
food = {"apple": "lecker"}
food
# Out:
# {'apple': 'lecker'}

# %%
fruits
# Out:
# {'apple': 'red', 'banana': 'yellow'}

# %%
fruits.keys() & food.keys()
# Out:
# {'apple'}

# %%
fruits
# Out:
# {'apple': 'red', 'banana': 'yellow'}

# %%
pairs_food = {
    ("mary", "john"): "apple",
    ("johny", "jon"): "banana"
}

# %%
t = 1,2

# %%
tuple([1,2,])
# Out:
# (1, 2)

# %%
name
# Out:
# 'fabrizio'

# %%
short
# Out:
# ['Hlloe', 'football', 'anohter name']

# %%
for idx, let in enumerate(name):
    print(idx, let)
# Out:
# 0 f
# 1 a
# 2 b
# 3 r
# 4 i
# 5 z
# 6 i
# 7 o

# %%
message, count = "end-of-loop", 1  # We can do multiple assignment with tuple unpacking

while count<4:
    print(count)
    count += 1   # equivalent to count = count + 1
# Out:
# 1
# 2
# 3

# %%
if 1 == 2:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
def sayhello(age, name="unknown"):
    print("hello", name, "you're", age)

# %%
sayhello(age=12, name="mary")
# Out:
# hello mary you're 12

# %%
def sayhello(*args, **kwargs):
    for arg in args:
        print("hello", arg)
        
    for k, v in kwargs.items():
        print("key", k, "value", v)

# %%
names = ["jon", "martha"]

# %%
sayhello("jon", "johny", jon=123, matt="nothing")
# Out:
# hello jon
# hello johny
# key jon value 123
# key matt value nothing

# %%
def f():
    1 +1 
    return None

# %%
a = f()

# %%
print(a)
# Out:
# None

# %%
a = 123

# %%
print(a)
# Out:
# 123

# %%
a + a
# Out:
# 246

# %%
sayhello(a)
# Out:
# hello 123

# %%
sayhello
# Out:
# <function __main__.sayhello(*args, **kwargs)>

# %%
myfunc = sayhello

# %%
def outer_func(inner_func):
    result = inner_func()
    return result

# %%
def hello():
    return "hello world"

# %%
outer_func(hello)
# Out:
# 'hello world'

# %%
result = []
for n in range(10):
    if n > 2:
        result.append(n)
result
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
def f(x):
    return x **2+1

# %%
result = {
    n: f(n)
    for n in range(10)
    if n == 2
}
result
# Out:
# {2: 5}

# %%
# Out:
# set

# %%
s = "university"
s
# Out:
# 'university'

# %%
s[0:-1]
# Out:
# 'universit'
