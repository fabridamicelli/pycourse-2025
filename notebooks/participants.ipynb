# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
partic = pd.read_csv("../data/participants.tsv", sep="\t")

# %%
partic = partic.dropna()

# %%
partic.head(5)
# Out:
#   participant_id   age sex
# 0        sub-301  25.0   F
# 1        sub-302  35.0   F
# 2        sub-303  23.0   F
# 4        sub-305  30.0   F
# 5        sub-306  29.0   M

# %%
plt.hist(partic["age"], bins=5)
plt.ylabel("Number of observations")
plt.xlabel("Age")
# Out:
# Text(0.5, 0, 'Age')

# %%
from collections import Counter

# %%
count = Counter(partic.sex)
count
# Out:
# Counter({'F': 22, 'M': 16})

# %%
plt.bar(["F", "M"], count.values())
# Out:
# <BarContainer object of 2 artists>

# %%
plt.barh(["F", "M"], count.values())
# Out:
# <BarContainer object of 2 artists>
